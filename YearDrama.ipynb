# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('imdb_top_1000.csv')

# %%
# Which year was most Drama movies released 

# Filter the DataFrame for drama genre
genre_drama = df[df['Genre'] == 'Drama']

# Convert 'Released_Year' to datetime and extract the year
df['Released_Year'] = pd.to_datetime(df['Released_Year'], errors='coerce')
df['year'] = df['Released_Year'].dt.year

# Count the number of drama movies released per year
count_drama_yearly = genre_drama.groupby('year')['Genre'].count()

# Calculate the average number of drama movies per year
avg_drama_yearly = count_drama_yearly / df.groupby('year')['Genre'].count()

# Plot the average number of drama movies released per year
avg_drama_yearly.plot(marker='o')
plt.title('Average Number of Drama Movies Released per Year')
plt.xlabel('Year')
plt.ylabel('Average Number of Drama Movies')
plt.show()

# %%
# Which year was most Drama movies released 

# Filter the DataFrame for drama genre
genre_drama = df[df['Genre'] == 'Drama']

# Convert 'Released_Year' to datetime and extract the year
df['Released_Year'] = pd.to_datetime(df['Released_Year'], errors='coerce')

# Count the number of drama movies released per year
count_drama_yearly = genre_drama.groupby('Released_Year')['Genre'].count()

# Calculate the average number of drama movies per year
avg_drama_yearly = count_drama_yearly / df.groupby('Released_Year')['Genre'].count()

plt.scatter(df['Released_Year'], df['Genre'])
plt.title('Average Number of Drama Movies Released per Year')
plt.xlabel('Year')
plt.ylabel('Average Number of Drama Movies')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df

# Filter the DataFrame for drama genre
genre_drama = df[df['Genre'] == 'Drama']

# Convert 'Released_Year' to datetime and extract the year
df['Released_Year'] = pd.to_datetime(df['Released_Year'], errors='coerce')

# Group by year and count the number of drama movies released per year
count_drama_yearly = genre_drama.groupby(df['Released_Year'].dt.year)['Genre'].count()

# Group by year and calculate the total number of movies released per year
total_movies_yearly = df.groupby(df['Released_Year'].dt.year)['Genre'].count()

# Calculate the average number of drama movies per year
avg_drama_yearly = count_drama_yearly / total_movies_yearly

# Plot the bar chart
plt.figure(figsize=(12, 6))
plt.bar(avg_drama_yearly.index, avg_drama_yearly.values, color='skyblue')
plt.title('Average Number of Drama Movies Released per Year')
plt.xlabel('Year')
plt.ylabel('Average Number of Drama Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
